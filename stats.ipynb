# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset/dataset_camera_vlog1.csv")
df2 = df
plt.bar(df2['Note'],df2['Nombre_avis'],  width=0.1)
#df2.pivot(index='Note',columns='index',values='Nombre_avis').plot(kind='bar')
# Out:
# <BarContainer object of 240 artists>

# %%
nb_avis =df2['Nombre_avis']
note = df2['Note'] 

def valuelabel(note,nb_avis):
    for i in range(len(note)):
        if nb_avis[i] > 2500:
            plt.text(nb_avis[i],note[i],df2['Product'][i],
                bbox = dict(facecolor = 'cyan', alpha =0.8),size=5)
fig = plt.figure(figsize= (15,10))
plt.barh(df2['Note'],df2['Nombre_avis'],color=np.random.rand(len(df['Product']),3),height=0.5)
valuelabel(note=note,nb_avis=nb_avis)
plt.xlabel("Nombre d'avis")
plt.ylabel("Nombre d'etoile") 
plt.title('Oh bien la montre')
plt.show()

# %%
nb_avis = df2['Nombre_avis']
note = df2['Note'] 

def valuelabel(note,nb_avis):
    for i in range(len(note)):
        if nb_avis[i] > 2500:
            plt.text(note[i],nb_avis[i],df2['Product'][i],ha='center',
                bbox = dict(facecolor = 'cyan', alpha =0.8),size=7,)
fig = plt.figure(figsize= (15,10))
plt.bar(df2['Note'],df2['Nombre_avis'],color=np.random.rand(len(df['Product']),3),width=0.5)
valuelabel(note=note,nb_avis=nb_avis)
plt.xlabel("Nombre d'avis")
plt.ylabel("Nombre d'etoile") 
plt.title('Les cameras les plus noté selon leur note sur amazon')
plt.show()
